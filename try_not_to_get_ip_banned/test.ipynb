# %%
import sys 

sys.path.append(r'C:\Users\DerDo\Desktop\fantasy_basketball_project')
from scrape_functions import *

# %%
scraper = Scrape_Functions()

# %%
# Use Basketball-Reference slug, e.g., LeBron James -> 'jamesle01'
slug = 'jamesle01'
season_end = 2024  # 2023–24 season

scraper.team_historical_data('LAL')
# Out:
#      Season   Lg                 Team   W   L  W/L%    Finish    SRS     \
# 0   2025-26  NBA   Los Angeles Lakers   0   0
# 1   2024-25  NBA  Los Angeles Lakers*  50  32  .610  1st of 5   1.45
# 2   2023-24  NBA  Los Angeles Lakers*  47  35  .573  3rd of 5   1.07
# 3   2022-23  NBA  Los Angeles Lakers*  43  39  .524  5th of 5   0.43
# 4   2021-22  NBA   Los Angeles Lakers  33  49  .402  4th of 5  -3.08
# ..      ...  ...                  ...  ..  ..   ...       ...    ... ..
# 73  1952-53  NBA  Minneapolis Lakers*  48  22  .686  1st of 5   5.54
# 74  1951-52  NBA  Minneapolis Lakers*  40  26  .606  2nd of 5   5.28
# 75  1950-51  NBA  Minneapolis Lakers*  44  24  .647  1st of 5   4.79
# 76  1949-50  NBA  Minneapolis Lakers*  51  17  .750  1st of 5   8.25
# 77  1948-49  BAA  Minneapolis Lakers*  44  16  .733  2nd of 6   6.80
#
#      Pace Rel Pace   ORtg Rel ORtg   DRtg Rel DRtg                   Playoffs  \
# 0
# ...

# %%
scraper.team_per36_data('ATL', '2025')
# Out:
#     Rk              Player Age Pos   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0    1          Trae Young  26  PG  76  76  2739  7.4  18.1  .411  ...  0.5
# 1    2       Dyson Daniels  21  SG  76  76  2571  6.4  12.9  .493  ...  1.7
# 2    3      Onyeka Okongwu  24   C  74  40  2064  6.8  11.9  .567  ...  3.8
# 3    4  Zaccharie Risacher  19  SF  75  73  1843  7.0  15.2  .458  ...  1.7
# 4    5       Jalen Johnson  23  SF  36  36  1284  7.6  15.2  .500  ...  1.7
# 5    6        Clint Capela  30   C  55  41  1176  6.7  11.9  .559  ...  5.3
# 6    7          Vit Krejci  24  PG  57  16  1153  4.5   9.1  .497  ...  0.7
# 7    8     De'Andre Hunter  27  SF  37   4  1064  7.7  16.6  .461  ...  0.9
# 8    9    Garrison Mathews  28  SG  47   2   830  4.4  11.1  .397  ...  0.6
# 9   10        Caris LeVert  30  SG  26   0   692  7.5  15.7  .482  ...  1.0
# 10  11        Terance Mann  28  SG  30   1   682  6.2  11.5  .541  ...  1.9
# ...
